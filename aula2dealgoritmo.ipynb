# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusbg006/algoritmos2/blob/main/aula2dealgoritmo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista = [50,1,0,60,13,24,99]

# %%
print(lista)
# Out:
# [50, 1, 0, 60, 13, 24, 99]

# %%
lista.remove(24)

# %%
print(lista)
# Out:
# [50, 1, 0, 60, 13, 99]

# %%
lista.append(77)

# %%
print(lista)
# Out:
# [50, 1, 0, 60, 13, 99, 77]

# %%
for i in lista:
  print(i)
# Out:
# 50
# 1
# 0
# 60
# 13
# 99
# 77

# %%
len(lista)
# Out:
# 7

# %%
for i in range(len(lista)):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def busca_simples(lista, alvo):
  for i in range( len(lista)):
    if lista[i] == alvo:
     return i
    else:
      print('nao é meu elemento')
  return -1

# %%
indice = busca_simples(lista, 99)
# Out:
# nao é meu elemento
# nao é meu elemento
# nao é meu elemento
# nao é meu elemento
# nao é meu elemento

# %%
print(indice)
# Out:
# 5
